# %%
import torch
from tqdm.notebook import tqdm

from transformers import BertTokenizer
from torch.utils.data import TensorDataset

from transformers import BertForSequenceClassification

import pickle

# %%
# Load: insert variable to load pickle into
df1 = pickle.load(open('../data/pickle/aristotle_hate.pickle', 'rb'))

# Load: insert variable to load pickle into
df2 = pickle.load(open('../data/pickle/aristotle_abusive.pickle', 'rb'))

# Load: insert variable to load pickle into
df3 = pickle.load(open('../data/pickle/aristotle_neutral.pickle', 'rb'))

# %%
df4 = pickle.load(open('../data/pickle/copenhagen_2.pickle', 'rb'))

# %%
df1
# Out:
#                                          public_metrics  \
# 0     {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1     {'retweet_count': 5, 'reply_count': 0, 'like_c...
# 2     {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 3     {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 4     {'retweet_count': 5, 'reply_count': 0, 'like_c...
# ...                                                 ...
# 1699  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1700  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 1701  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1702  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 1703  {'retweet_count': 0, 'reply_count': 1, 'like_c...
#
#                                                    text                  id  \
# 0     I hate er chase because if the Bitch that work...  850433664890544128
# 1     RT @nyctophil3: Pineapples do not belong on pi...  850100742035836929
# ...

# %%
# 1: pd.Series, 2: list or pd.index, each item labels individual bars
Y = 
X = 
fig = plt.figure(figsize = (8, 5))
g = sns.barplot(X, Y, palette='deep')
# Insert title for graph, y axis label, and x axis label
g.set(title = 'deep', ylabel = '', xlabel = '')
plt.tight_layout()
plt.show()
# Insert filename to save
plt.savefig('')
